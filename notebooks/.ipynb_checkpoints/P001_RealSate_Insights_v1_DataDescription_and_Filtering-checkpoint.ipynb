# %% [markdown]
# # Imports

# %%
import numpy             as np
import pandas            as pd
import seaborn           as sns
import plotly.express    as px
import matplotlib.pyplot as plt

from IPython.core.display  import HTML
from tabulate              import tabulate
from geopy.geocoders       import Nominatim

# %% [markdown]
# ## Helper Functions

# %%
def jupyter_settings():
    # %matplotlib inline
        
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = (20,15)
    plt.rcParams['font.size'] = 25
    
    display( HTML( '<style>.container { width:90% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()
    sns.set_theme(style = 'darkgrid', font_scale = 2)
    sns.set_style("darkgrid")

# %%
jupyter_settings()
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ## Loading Data

# %%
df_raw = pd.read_csv(r'../datasets/raw/kc_house_data.csv')

# %% [markdown]
# # Data Description

# %%
df1=df_raw.copy()

# %% [markdown]
# ## Rename Columns

# %%
# checking columns names
df1.columns # nothing to rename
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ## Data Dimension

# %%
print('Number of rows: {}' .format (df1.shape[0]))
print('Number of columns: {}' .format (df1.shape[1]))
# Out:
# Number of rows: 21613
# Number of columns: 21

# %% [markdown]
# ## Data Types

# %%
df1.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180      5650     1.0           0     0          3      7        1180              0      1955             0    98178  47.5112 -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570      7242     2.0           0     0          3      7        2170            400      1951          1991    98125  47.7210 -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0         2       1.00          770     10000     1.0           0     0          3      6         770              0      1933             0    98028  47.7379 -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960      5000     1.0           0     0          5      7        1050            910      1965             0    98136  47.5208 -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680      8080     1.0           0     0          3      8        1680              0      1987             0    98074  47.6168 -122.045           1800        7503

# %%
df1.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# ## Check NA

# %%
df1.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ## Fill out NA

# %% [markdown]
# ## Change Variables Types

# %%
# changing 'date' type from OBJECT to DATE or INT

# checking DATES types
print(df1[['date','yr_built','yr_renovated']].head(),'\n')
print(df1[['date','yr_built','yr_renovated']].dtypes)

# changing dtypes
df1['date']         = pd.to_datetime(df1['date'],         format='%Y-%m-%d')
# df1['yr_built']     = pd.to_datetime(df1['yr_built'],     format='%Y-%m-%d')
# df1['yr_renovated'] = pd.to_datetime(df1['yr_renovated'], format='%Y-%m-%d')

# checking DATES types
print("")
print(df1[['date','yr_built','yr_renovated']].dtypes)
df1[['date','yr_built','yr_renovated']].head()


# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object
# Out:
#               date  yr_built  yr_renovated
# 0  20141013T000000      1955             0
# 1  20141209T000000      1951          1991
# 2  20150225T000000      1933             0
# 3  20141209T000000      1965             0
# 4  20150218T000000      1987             0
#
# date            object
# yr_built         int64
# yr_renovated     int64
# dtype: object
#
# date            datetime64[ns]
# yr_built                 int64
# yr_renovated             int64
# dtype: object
#         date  yr_built  yr_renovated
# 0 2014-10-13      1955             0
# 1 2014-12-09      1951          1991
# 2 2015-02-25      1933             0
# 3 2014-12-09      1965             0
# 4 2015-02-18      1987             0

# %% [markdown]
# ## Dropping Duplicates

# %%
print(df1.shape[0], 'number of rows')
print(df1['id'].unique().shape[0], 'uniques ids')
print(df1.shape[0] - df1['id'].unique().shape[0], '  number of duplicated ids')
# Out:
# 21613 number of rows
# 21436 uniques ids
# 177   number of duplicated ids

# %%
# sorting dataframe by date
df1 = df1.sort_values('date', ascending=True)

# deleting ids that appears first
df1 = df1.drop_duplicates(subset='id', keep='last')

print('new shape:', df1.shape)
# Out:
# new shape: (21436, 21)

# %% [markdown]
# ## Descriptive Statistical

# %%
num_df1 = df1.select_dtypes(include=['int64','float64'])
cat_df1 = df1.select_dtypes(exclude=['int64','float64','datetime64[ns]'])

# %% [markdown]
# ### Numerical Attributes

# %%
num_df1.shape
# Out:
# (21436, 20)

# %%
# central tendendy - mean, median
ct1 = pd.DataFrame(num_df1.apply(np.mean)).T
ct2 = pd.DataFrame(num_df1.apply(np.median)).T

# dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame(num_df1.apply(np.std)).T
d2 = pd.DataFrame(num_df1.apply(min)).T
d3 = pd.DataFrame(num_df1.apply(max)).T
d4 = pd.DataFrame(num_df1.apply(lambda x: x.max() - x.min())).T
d5 = pd.DataFrame(num_df1.apply(lambda x: x.skew())).T
d6 = pd.DataFrame(num_df1.apply(lambda x: x.kurtosis)).T

# concatenate 
m = pd.concat([d2,d3,d4,ct1,ct2,d1,d5,d6]).T.reset_index()
m.columns = ['attributes','min','max','range','mean','median','std','skew','kurtosis']
m
# Out:
#        attributes        min           max         range               mean        median                std       skew                                           kurtosis
# 0              id  1000102.0  9900000190.0  9899000088.0  4580765328.177878  3904921185.0  2876522535.726108   0.243231  <bound method NDFrame._add_numeric_operations....
# 1           price    75000.0     7700000.0     7625000.0      541649.962726      450000.0      367306.361583   4.036107  <bound method NDFrame._add_numeric_operations....
# 2        bedrooms        0.0          33.0          33.0           3.371571           3.0           0.929183    1.98986  <bound method NDFrame._add_numeric_operations....
# 3       bathrooms        0.0           8.0           8.0           2.117349          2.25           0.769895   0.510181  <bound method NDFrame._add_numeric_operations....
# 4     sqft_living      290.0       13540.0       13250.0        2082.704936        1920.0         919.125029   1.471021  <bound method NDFrame._add_numeric_operations....
# 5        sqft_lot      520.0     1651359.0     1650839.0       15135.637852        7614.0       41537.651696  13.043673  <bound method NDFrame._add_numeric_operations....
# 6          floors        1.0           3.5           2.5           1.496198           1.5           0.540376   0.610479  <bound method NDFrame._add_numeric_operations....
# 7      waterfront        0.0           1.0           1.0           0.007604           0.0           0.086869  11.337321  <bound method NDFrame._add_numeric_operations....
# 8            view        0.0           4.0           4.0           0.235118           0.0           0.767074   3.386735  <bound method NDFrame._add_numeric_operations....
# 9       condition        1.0           5.0           4.0           3.410384           3.0            0.65022   1.036192  <bound method NDFrame._add_numeric_operations....
# 10          grade        1.0          13.0          12.0           7.661737           7.0           1.174229   0.770357  <bound method NDFrame._add_numeric_operations....
# 11     sqft_above      290.0        9410.0        9120.0         1790.96044        1560.0         829.007154   1.444221  <bound method NDFrame._add_numeric_operations....
# 12  sqft_basement        0.0        4820.0        4820.0         291.744495           0.0         442.771655   1.576873  <bound method NDFrame._add_numeric_operations....
# 13       yr_built     1900.0        2015.0         115.0        1971.098433        1975.0          29.384591  -0.474577  <bound method NDFrame._add_numeric_operations....
# 14   yr_renovated        0.0        2015.0        2015.0            84.7298           0.0         402.421625   4.539547  <bound method NDFrame._add_numeric_operations....
# 15        zipcode    98001.0       98199.0         198.0       98077.862288       98065.0          53.468124   0.408129  <bound method NDFrame._add_numeric_operations....
# 16            lat    47.1559       47.7776        0.6217          47.560156        47.572           0.138598  -0.488165  <bound method NDFrame._add_numeric_operations....
# 17           long   -122.519      -121.315         1.204        -122.213697       -122.23           0.140893   0.881923  <bound method NDFrame._add_numeric_operations....
# 18  sqft_living15      399.0        6210.0        5811.0        1988.314378        1840.0         685.683099   1.105845  <bound method NDFrame._add_numeric_operations....
# 19     sqft_lot15      651.0      871200.0      870549.0        12785.96128        7620.0       27374.828923    9.49538  <bound method NDFrame._add_numeric_operations....

# %% [markdown]
# ### Categorical Attributes

# %%
cat_df1.shape # no attributes
# Out:
# (21436, 0)

# %% [markdown]
# # Variable Filtering

# %%
df2=df1.copy()

# %%
df2 = df2.drop (['view','sqft_living15','sqft_lot15'], axis=1)


# view          	An index from 0 to 4 of how good the view of the property was

# sqft_living15 	The square footage of interior housing living space for the nearest 15 neighbors
# sqft_lot15    	The square footage of the land lots of the nearest 15 neighbors

# %%
# checking properties 'sqft_living' by number of 'bedrooms'
print(df2[['bedrooms','sqft_living']].groupby(['bedrooms']).mean().sort_values('sqft_living', ascending=True))
print(df2[['id','bedrooms']].groupby(['bedrooms']).count(),'\n')

# droping properties with bedrooms equal 0, 11 or 33 (understanding as outliers)
df2 = df2[ (df2['bedrooms']!=0) & (df2['bedrooms']!=11) & (df2['bedrooms']!=33) ]
# Out:
#           sqft_living
# bedrooms
# 1          884.938144
# 2         1240.540205
# 33        1620.000000
# 0         1707.846154
# 3         1807.596855
# 4         2555.997810
# 11        3000.000000
# 5         3054.823455
# 6         3310.758491
# 10        3706.666667
# 9         3775.000000
# 8         3800.000000
# 7         3974.210526
#             id
# bedrooms
# 0           13
# 1          194
# 2         2736
# 3         9731
# 4         6849
# 5         1586
# 6          265
# 7           38
# 8           13
# 9            6
# 10           3
# 11           1
# 33           1

# %% [markdown]
# # Feature Engineering

# %%
df3 = df2.copy()

# %% [markdown]
# ## Mind Map Hypothesis

# %% [markdown]
# ## Creating Hypothesis

# %% [markdown]
# ## Feature Engineering

# %%
# mean price by zipcode

# %%
# decision: 1 = buy, 0 = hold

# %%
# sale price suggestion

# %%
# expected profit

# %% [markdown]
# # EDA

# %%
df4=df3.copy()

# %%
num_df4 = df4.select_dtypes(include=['int64','float64'])
cat_df4 = df4.select_dtypes(exclude=['int64','float64','datetime64[ns]'])

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Response Variable

# %%
sns.displot(df4['price'], legend=True);

# %% [markdown]
# ### Numerical Variables

# %%
num_df4.hist(bins=20);

# %% [markdown]
# ### Categorical Variables

# %%
cat_df4.shape
# Out:
# (21421, 0)

# %% [markdown]
# ## <font color='red'> Bivariate Analysis

# %%
print('Hypothesis Resume \n\n')
tab = [ ['Hypothesis', 'Conclusion', 'Relevance'],
        ['H1','False','Low'],
        ['H2','False','Medium'],
        ['H3','False','Medium'],
        ['H4','False','Low'],
        ['H5','False','Low'],
        ['H6','False','Low'],
        ['H7','False','Low'],
        ['H8','False','Low'],
        ['H9','False','High'],
        ['H10','True','High'],
        ['H11','True','High'],
        ['H12','True','High'],
      ]

print(tabulate(tab, headers = 'firstrow'))
# Out:
# Hypothesis Resume
#
#
# Hypothesis    Conclusion    Relevance
# ------------  ------------  -----------
# H1            False         Low
# H2            False         Medium
# H3            False         Medium
# H4            False         Low
# H5            False         Low
# H6            False         Low
# H7            False         Low
# H8            False         Low
# H9            False         High
# H10           True          High
# H11           True          High
# H12           True          High

# %% [markdown]
# ### H1

# %% [markdown]
# ## Multivatiate Analysis

# %% [markdown]
# ### Numerical Attributes

# %%
correlation = num_df4.corr(method='pearson')
sns.set(font_scale=1.2)
sns.heatmap(correlation, cmap='YlOrRd', annot=True, 
            annot_kws= {'fontsize':'medium'},
            linewidths=0.8, square=True );

# %% [markdown]
# ### Categorical Attributes

# %%
cat_df4.shape
# Out:
# (21598, 0)

# %% [markdown]
# # Conclusion and Visualization

# %%
df5=df4.copy()

# %%
# Mainly Insights

# %%
# Decision Dataframe Overview

# %%
# Expected Profit Overview
